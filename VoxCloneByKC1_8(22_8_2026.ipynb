# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai5t-bytSaiYarPyi/My-VOD-Bot/blob/main/VoxCloneByKC1_8(22_8_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Cell 1 — Install Dependencies
# !pip install -q gdown python-telegram-bot librosa soundfile torch torchaudio transformers \
    einops inflect addict wetext modelscope datasets huggingface-hub \
    pydantic tqdm simplejson sortedcontainers nest_asyncio pypdf
# !apt-get install -y -qq ffmpeg
# !apt-get install -y -qq rubberband-cli

# %%
## Cell 2 — Download Compiled Module
import os
import gdown

SO_FILE_ID = "1vIZXL8NwdyNVrOqnjFNbkvXKMdim0ndE"
# .so ဖိုင်ကို bot_core.so နာမည်ဖြင့် ဒေါင်းယူခြင်း
gdown.download(id=SO_FILE_ID, output="/content/bot_core.so", quiet=False)

# Colab ရဲ့ current Python version အလိုက် import-ready filename ဖြင့် copy ကူးခြင်း
import sysconfig
ext_tag = sysconfig.get_config_var("EXT_SUFFIX")   # ဥပမာ: .cpython-311-x86_64-linux-gnu.so
# !cp /content/bot_core.so /content/bot_core{ext_tag}
print("Ready as:", f"/content/bot_core{ext_tag}")

# %%
## Cell 3 — Run Bot
import sys

if "/content" not in sys.path:
    sys.path.insert(0, "/content")
# Save a copy in Drive မလုပ်ရသေးရင်အရင်လုပ်ပါ
BOT_TOKEN = "8393252464:AAF9ZhNVyofiw0vbRTskwlpyPON-HWiw9lY"   # ← ကိုယ်ပိုင် bot token နဲ့ အစားထိုးပါ

import bot_core
bot_core.run(BOT_TOKEN)
